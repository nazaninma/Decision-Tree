# %% [markdown]
# ## COVID-19 challenge
#
# >COVID-19 testing data for trend analysis and policy-making.
# >
# >TODO: for more information read [dataset page](https://www.kaggle.com/datasets/expertjha001/corona-tested-dataset)

# %% [markdown]
# ## Importing Libraries

# %%
import sys
sys.path.append('..')
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from decision_tree import MultiNodeCategoricalDecisionTree

# %%
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("expertjha001/corona-tested-dataset")

# print("Path to dataset files:", path)


# !unzip C:\dev\home\AIhw\project1-decision-tree\project1-decision-tree\corona\archive.zip
# Out:
# Archive:  C:\dev\home\AIhw\project1-decision-tree\project1-decision-tree\corona\archive.zip
#   inflating: corona_tested_006.csv

# %%
df = pd.read_csv('C:\\dev\\home\\AIhw\\project1-decision-tree\\project1-decision-tree\\corona\\corona_tested_006.csv')  
print(df.head(10))
# Out:
#    Ind_ID   Test_date Cough_symptoms  Fever Sore_throat Shortness_of_breath  \
# 0       1  11-03-2020           True  False        True               False
# 1       2  11-03-2020          False   True       False               False
# 2       3  11-03-2020          False   True       False               False
# 3       4  11-03-2020           True  False       False               False
# 4       5  11-03-2020           True  False       False               False
# 5       6  11-03-2020           True  False       False               False
# 6       7  11-03-2020          False  False       False               False
# 7       8  11-03-2020          False   True       False               False
# 8       9  11-03-2020           True  False       False               False
# 9      10  11-03-2020           True  False        True               False
#
#   Headache    Corona Age_60_above  Sex           Known_contact
# 0    False  negative          NaN  NaN                  Abroad
# ...

# %% [markdown]
# ## Loading the Dataset
#
# TODO: Replace this section with code to load your actual dataset.
#
# In this section, you should:
# 1. Load your dataset from a file (CSV, Excel, etc.) or a database
# 2. Display basic information about the dataset (shape, columns, etc.)
# 3. Show the first few rows of the data

# %%
# TODO: Load the actual dataset
# def load_dataset():
#     # This is a placeholder. Replace with actual data loading code.
#     data = pd.DataFrame({
#         'feature1': ['A', 'B', 'C', 'A', 'B'] * 20,
#         'feature2': ['X', 'Y', 'Z', 'X', 'Y'] * 20,
#         'feature3': ['P', 'Q', 'R', 'P', 'Q'] * 20,
#         'target': [0, 1, 0, 1, 0] * 20
#     })
#     return data

# data = load_dataset()
# print(data.head())
# Out:
#   feature1 feature2 feature3  target
# 0        A        X        P       0
# 1        B        Y        Q       1
# 2        C        Z        R       0
# 3        A        X        P       1
# 4        B        Y        Q       0

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# TODO: Perform exploratory data analysis on your dataset.
#
# In this section, you should:
# 1. Analyze the distribution of features and target variable
# 2. Check for missing values and outliers
# 3. Visualize relationships between features and the target variable
# 4. Identify any patterns or correlations in the data

# %%
# TODO: Add your EDA code here
# Example:
print(df.describe())
print(df.isnull().sum())
# Add visualizations using matplotlib or seaborn
# Out:
#               Ind_ID
# count  278848.000000
# mean   139424.500000
# std     80496.628269
# min         1.000000
# 25%     69712.750000
# 50%    139424.500000
# 75%    209136.250000
# max    278848.000000
# Ind_ID                      0
# Test_date                   0
# Cough_symptoms            252
# Fever                     252
# Sore_throat                 1
# Shortness_of_breath         1
# Headache                    1
# Corona                      0
# Age_60_above           127320
# Sex                     19563
# Known_contact               0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
print(df.describe())
print(df.isnull().sum())
# Add visualizations using matplotlib or seaborn
plt.figure(figsize=(12, 6))

# Box plot for 'Survived' by 'Sex'
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
sns.boxplot(data=df, x='Shortness_of_breath', y='Corona')
plt.title('Box plot of Corona by Shortness_of_breath')

# Box plot for 'Survived' by 'Cabin'
# If Cabin has too many categories, consider aggregating them
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
sns.boxplot(data=df, x='Sore_throat', y='Corona')
plt.title('Box plot of Sore_throat by Corona')
 # Rotate x-axis labels for better visibility

# Show the plots
plt.tight_layout()  # Adjusts the layout for better spacing
plt.show()
# Out:
#               Ind_ID
# count  278848.000000
# mean   139424.500000
# std     80496.628269
# min         1.000000
# 25%     69712.750000
# 50%    139424.500000
# 75%    209136.250000
# max    278848.000000
# Ind_ID                      0
# Test_date                   0
# Cough_symptoms            252
# Fever                     252
# Sore_throat                 1
# Shortness_of_breath         1
# Headache                    1
# Corona                      0
# Age_60_above           127320
# Sex                     19563
# Known_contact               0
# dtype: int64

# %% [markdown]
# ## Preprocessing
#
# TODO: Preprocess your data to prepare it for the decision tree model.
#
# In this section, you should:
# 1. Handle missing values (if any)
# 2. Encode categorical variables
# 3. Split the data into features (X) and target (y)
# 4. Split the data into training and testing sets
#
# Note: You should encode your data before splitting it into features and target,
# because the decision tree classifier works with categorical data.
#
# Example of encoding data:

# %%
"""
TODO: Add your preprocessing code here
Note : you should encode your data before split it into features and target ,
because decision tree classifier just work with categorical data

example of encoding data :

le = LabelEncoder()
X = data.drop('target', axis=1)
y = data['target']

Encode categorical features
Features need to be encoded using OrdinalEncoder search about this function in sklearn library

"""

# Split the data

df.isnull().any()
# X_train, X_test, y_train, y_test = # TODO : Split dataset using sklearn library ,naturally you should search about this function
# print("Training set shape:", X_train.shape)
# print("Test set shape:", X_test.shape)
# Out:
# Ind_ID                 False
# Test_date              False
# Cough_symptoms          True
# Fever                   True
# Sore_throat             True
# Shortness_of_breath     True
# Headache                True
# Corona                 False
# Age_60_above            True
# Sex                     True
# Known_contact          False
# dtype: bool

# %%
print(df['Cough_symptoms'].dtype)
print(df['Fever'].dtype)
print(df['Sore_throat'].dtype)
print(df['Shortness_of_breath'].dtype)
print(df['Headache'].dtype)

print(df['Age_60_above'].dtype)
print(df['Sex'].dtype)
# Out:
# object
# object
# object
# object
# object
# object
# object

# %% [markdown]
# ## Training the Model

# %%
#deleting


# Plot the distribution of Corona test results by Sex
df = df.drop(columns=['Age_60_above'])
df = df.drop(columns=['Sex'])

df.isnull().any()
# Out:
# Ind_ID                 False
# Test_date              False
# Cough_symptoms          True
# Fever                   True
# Sore_throat             True
# Shortness_of_breath     True
# Headache                True
# Corona                 False
# Known_contact          False
# dtype: bool

# %%
"""
TODO: Add your preprocessing code here
Note : you should encode your data before split it into features and target ,
because decision tree classifier just work with categorical data

example of encoding data :

le = LabelEncoder()


X = data.drop('target', axis=1)
y = data['target']

Encode categorical features
Features need to be encoded using OrdinalEncoder search about this function in sklearn library

"""


import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer





fill_symptoms = SimpleImputer(strategy='most_frequent')
df['Cough_symptoms'] = fill_symptoms.fit_transform(df['Cough_symptoms'].values.reshape(-1, 1)).ravel()

Fever_fill = SimpleImputer(strategy='most_frequent')
df['Fever'] = Fever_fill.fit_transform(df['Fever'].values.reshape(-1, 1)).ravel()

sore_fill = SimpleImputer(strategy='most_frequent')
df['Sore_throat'] = sore_fill.fit_transform(df['Sore_throat'].values.reshape(-1, 1)).ravel()

breath_fill = SimpleImputer(strategy='most_frequent')
df['Shortness_of_breath'] = breath_fill.fit_transform(df['Shortness_of_breath'].values.reshape(-1, 1)).ravel()

head_fill = SimpleImputer(strategy='most_frequent')
df['Headache'] = head_fill.fit_transform(df['Headache'].values.reshape(-1, 1)).ravel()

# head_fill=SimpleImputer(strategy='most_frequent')
# data['Headache']=head_fill.fit_transform(data['Headache'])


# sex_fill=SimpleImputer(strategy='most_frequent')
# data['Sex']=sex_fill.fit_transform(data['Sex'])


#first try: delete the age 60 above from it




#map the data to numeric version
bool_map={True:1, False:0}
df['Cough_symptoms']=df['Cough_symptoms'].map(bool_map).astype(int)
df['Fever']=df['Fever'].map(bool_map).astype(int)
df['Sore_throat']=df['Sore_throat'].map(bool_map).astype(int)
df['Shortness_of_breath']=df['Shortness_of_breath'].map(bool_map).astype(int)
df['Headache']=df['Headache'].map(bool_map).astype(int)

result_map={'negative':0,'positive':1,'other':2}
df['Corona']=df['Corona'].map(result_map).astype(int)



x=df.drop(columns=['Ind_ID','Test_date','Corona','Known_contact'])
y=df['Corona']

# Split the data
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
# print("Training set shape:", X_train.shape)
# print("Test set shape:", X_test.shape)

# %%
# Initialize and train the model

from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

kf = KFold(n_splits=5, shuffle=True, random_state=5)
fold_accuracies = []
for train_index, test_index in kf.split(x):
    X_train, X_test = x.iloc[train_index], x.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    model = MultiNodeCategoricalDecisionTree(max_depth=5, min_samples_split=2)
    model.fit(X_train.values, y_train.values)
    y_pred = model.predict(X_test.values)
    y_pred = np.array(y_pred).astype(int)
    y_test = np.array(y_test).astype(int)
    accuracy = accuracy_score(y_test, y_pred)
    fold_accuracies.append(accuracy)
    # print(f"Fold accuracy: {accuracy:.4f}")

average_accuracy = np.mean(fold_accuracies)
print(f"Average accuracy across all folds: {average_accuracy:.4f}")
# Out:
# Average accuracy across all folds: 0.8996

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer, f1_score, accuracy_score
import numpy as np
model = MultiNodeCategoricalDecisionTree(max_depth=5, min_samples_split=2)

kf = KFold(n_splits=6, shuffle=True, random_state=2)

f1_scorer = make_scorer(f1_score, average='weighted')

accuracy_scores = cross_val_score(model, x, y, cv=kf, scoring='accuracy')


f1_scores = cross_val_score(model, x, y, cv=kf, scoring=f1_scorer)

print(f"Average F1 score across folds: {np.mean(f1_scores):.4f}")

# %% [markdown]
# ## Evaluating the Model

# %%
# Make predictions
y_pred = model.predict(X_test.values)

# Ensure y_pred is in the same format as y_test
y_pred = np.array(y_pred).astype(int)
y_test = np.array(y_test).astype(int)

# Calculate accuracy and cross validation

print(f"Accuracy: {accuracy:.4f}")

# %% [markdown]
# ## Feature Importances

# %%
# Display feature importances
feature_importances = pd.DataFrame({
    'feature': X.columns,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

print(feature_importances)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("expertjha001/corona-tested-dataset")
#
# ModuleNotFoundError: No module named 'kagglehub'

# %% [markdown]
# ## Preparing Submission
